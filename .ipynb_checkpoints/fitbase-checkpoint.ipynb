# %%
import torch
import pickle
import numpy as np

# %%
with open(r"C:\Users\Neela\Documents\GitHub\EntityAspectLinking\picklefiles\final_eal_random.pkl", 'rb') as eal:
    data = pickle.load(eal)
    
ent = [data[i][0] for i in range(len(data))]

asp = [data[i][1] for i in range(len(data))]

# %%
PTH = r"C:\Users\Neela\Documents\GitHub\EntityAspectLinking\picklefiles"

# %%
def read_tensor(filename):
    with open(f'{PTH}\\{filename}', 'rb') as f:
        emb = np.load(f, allow_pickle = True)
    return emb

# %%
ent_emb = read_tensor('random_targetentemb.pkl')

asp_emb = read_tensor('random_aspemb.pkl')

context_emb = read_tensor('random_paragraphemb.pkl')

# %%
aspect = [el[1] for el in data]
lngth = [len(el['candidate_aspects']) - 1 for el in aspect]
asp_count = sum([len(el['candidate_aspects']) for el in aspect])

# %%
asp_count
# Out:
# 16383

# %%
import urllib
def decode(str):
    return urllib.parse.unquote(str)

# %%
decode('Hell%C3%B6%20W%C3%B6rld%40Python')
# Out:
# 'Hellö Wörld@Python'

# %%
i = 0
j = 0
check = 0
yo = 0
unid_ls = []
while(i < asp_count):
    aspect = asp[j]['true_aspect']
    aspect = decode(aspect)
    #print(j, "Entity")
    #tokens = tokenizer.tokenize(aspect)
    #print(i, 'first')
    #print("This shit", tokens)
    i+=1    
    this = 0
    
    #if len(asp[j]['candidate_aspects']) == 0:
        #print("Ache", j)
    for cand in asp[j]['candidate_aspects']:
        if i >= asp_count:
            #print("Yes ekhane")
            break
        if cand['aspect_name'] == aspect:
            check += 1
        if cand['aspect_name'] != aspect:
            this += 1
            casp = cand['aspect_name']
            #print(cand['aspect_name'], aspect)
            #tokens = tokenizer.tokenize(casp)
            #print(tokens)
            #print(i, "second")
            i+=1
    if this == len(asp[j]['candidate_aspects']):
        yo += 1  
        unid_ls.append(j)     
        #print("Found it", aspect, j)
            
    j += 1

# %%
i = 0
j = 0
check = 0
yo = 0
ind = []
while(i < asp_count):
    aspect = asp[j]['true_aspect']
    aspect = decode(aspect)
    #print(j, "Entity")
    #tokens = tokenizer.tokenize(aspect)
    #print(i, 'first')
    #print("This shit", tokens)
    i+=1    
    this = 0
    
    #if len(asp[j]['candidate_aspects']) == 0:
        #print("Ache", j)
    for cand in asp[j]['candidate_aspects']:
        if i >= asp_count:
            #print("Yes ekhane")
            break
        if j in unid_ls and decode(aspect) in str(cand["aspect_name"]):
            ind.append(i) 
            i += 1          
            continue
        #if len(cand['aspect_name']) == 0:
            #print("yes")
            #i += 1
            #continue     
        #print(j)
        #if cand['aspect_name'] == aspect:
            #check += 1
        #if cand['aspect_name'] != aspect:
            #this += 1
            #casp = cand['aspect_name']
            #print(cand['aspect_name'], aspect)
            #tokens = tokenizer.tokenize(casp)
            #print(tokens)
            #print(i, "second")
        i+=1
    #if this == len(asp[j]['candidate_aspects']):
        #yo += 1           
        #print("Found it", aspect, j)
            
    j += 1

# %%
ind
# Out:
# [9311, 10136]

# %%
dataset = np.zeros((asp_count, 201 + context_emb.shape[1]))

# %%
context_emb.shape
# Out:
# torch.Size([2500, 384])

# %%
i = 0
k = 0
for _ in range(len(dataset)):
    while(k < len(lngth)):
        dataset[i, : ent_emb.shape[1]] = ent_emb[k]
        dataset[i, ent_emb.shape[1] : ent_emb.shape[1] + context_emb.shape[1]] = context_emb[k]
        dataset[i, ent_emb.shape[1] + context_emb.shape[1] : -1] = asp_emb[i]
        dataset[i, -1] = 1
        i += 1
        for _ in range(lngth[k]):
            if i in ind:
                print('Here')
                i += 1
                continue
            dataset[i, : ent_emb.shape[1]] = ent_emb[k]
            dataset[i, ent_emb.shape[1] : ent_emb.shape[1] + context_emb.shape[1]] = context_emb[k]
            dataset[i, ent_emb.shape[1] + context_emb.shape[1] : -1] = asp_emb[i]
            dataset[i, -1] = 0
            i += 1
        k += 1
# Out:
# Here
# Here

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = dataset[:,:-1]
sc = StandardScaler()
X = sc.fit_transform(X)
y = dataset[:,-1]

# %%
undersample = RandomUnderSampler(sampling_strategy='majority')

# %%
X, y = undersample.fit_resample(X, y)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [03:13<00:00,  6.69s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.66               0.66     0.66      0.66
# XGBClassifier                      0.64               0.64     0.64      0.64
# BaggingClassifier                  0.64               0.64     0.64      0.64
# AdaBoostClassifier                 0.63               0.63     0.63      0.63
# RandomForestClassifier             0.61               0.61     0.61      0.61
# DecisionTreeClassifier             0.61               0.61     0.61      0.61
# ExtraTreesClassifier               0.60               0.60     0.60      0.60
# SVC                                0.57               0.57     0.57      0.57
# KNeighborsClassifier               0.57               0.57     0.57      0.57
# NuSVC                              0.56               0.56     0.56      0.56
# CalibratedClassifierCV             0.56               0.56     0.56      0.55
# RidgeClassifierCV                  0.55               0.55     0.55      0.55
# LogisticRegression                 0.55               0.55     0.55      0.55
# ExtraTreeClassifier                0.55               0.55     0.55      0.55
# RidgeClassifier                    0.55               0.55     0.55      0.55
# LinearDiscriminantAnalysis         0.55               0.55     0.55      0.55
# PassiveAggressiveClassifier        0.55               0.55     0.55      0.54
# LinearSVC                          0.54               0.54     0.54      0.54
# NearestCentroid                    0.53               0.53     0.53      0.51
# GaussianNB                         0.53               0.53     0.53      0.49
# Perceptron                         0.53               0.53     0.53      0.53
# BernoulliNB                        0.53               0.53     0.53      0.52
# QuadraticDiscriminantAnalysis      0.52               0.53     0.53      0.52
# SGDClassifier                      0.52               0.52     0.52      0.52
# DummyClassifier                    0.49               0.50     0.50      0.32
# LabelSpreading                     0.51               0.50     0.50      0.35
# LabelPropagation                   0.51               0.50     0.50      0.35
#
#                                Time Taken
# Model
# LGBMClassifier                       4.69
# XGBClassifier                       15.88
# BaggingClassifier                   31.10
# AdaBoostClassifier                  21.40
# RandomForestClassifier              12.65
# DecisionTreeClassifier               5.23
# ExtraTreesClassifier                 4.14
# SVC                                 11.22
# KNeighborsClassifier                 0.86
# NuSVC                               12.41
# CalibratedClassifierCV              44.43
# RidgeClassifierCV                    2.17
# LogisticRegression                   0.54
# ExtraTreeClassifier                  0.27
# RidgeClassifier                      0.33
# LinearDiscriminantAnalysis           2.36
# PassiveAggressiveClassifier          0.49
# LinearSVC                           11.35
# NearestCentroid                      0.24
# GaussianNB                           0.30
# Perceptron                           0.30
# BernoulliNB                          0.35
# QuadraticDiscriminantAnalysis        3.39
# SGDClassifier                        2.02
# DummyClassifier                      0.21
# LabelSpreading                       2.83
# LabelPropagation                     2.52

# %%
y_test.shape
# Out:
# (1500,)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
