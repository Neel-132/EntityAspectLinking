# %%
import torch
import pickle

# %%
PTH = r'.\picklefiles'

with open(f'{PTH}\\graph_trainsmall_linkpred.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
device = 'cpu'
data = data.to(device)

# %%
with open(f'{PTH}\\graph_trainsmall_linkpred_cpu.pkl', 'wb') as f:
    pickle.dump(data, f)
