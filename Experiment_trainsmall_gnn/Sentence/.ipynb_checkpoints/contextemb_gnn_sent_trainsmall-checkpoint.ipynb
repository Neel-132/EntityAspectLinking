# %%
import embedding
from transformers import BertTokenizer
from tqdm import tqdm
import torch
import pickle

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
PTH = r'.\picklefiles'
with open(f'{PTH}\\eal_gnn_trainsmall.pkl', 'rb') as eal:
    data = pickle.load(eal)
eal.close()

ent = [data[i][0] for i in range(len(data))]

asp = [data[i][1] for i in range(len(data))]

# %%
import re
def preprocess(text):
    text = text.lower()
    text = re.sub(r"[^\w\s]","",text)
    text = re.sub(r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))","",text)
    text = re.sub("<(\"[^\"]*\"|'[^']*'|[^'\">])*>","",text)    
    return text

# %%
txtemb = embedding.TextEmbedding(device = device)

# %%
sentemb = torch.zeros(len(ent),384).to(device)
for i in tqdm(range(len(ent))):
    token = ent[i]["sentence"]
    sent = preprocess(token)
    output = txtemb(sent)    
    sentemb[i] = output
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5498/5498 [00:55<00:00, 98.85it/s]

# %%
with open(f'{PTH}\\sentemb_gnn_trainsmall.pkl', 'wb') as f:
    pickle.dump(sentemb, f)
print("Dumped")
f.close()
# Out:
# Dumped
