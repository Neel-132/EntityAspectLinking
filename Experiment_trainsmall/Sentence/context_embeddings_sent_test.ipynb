# %%
import embedding
from transformers import BertTokenizer
from tqdm import tqdm
import torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import pickle
import torch
PTH = r'.\picklefiles'
with open(f"{PTH}\\eal_test.pkl", 'rb') as eal:
    data = pickle.load(eal)

ent = [data[i][0] for i in range(len(data))]

asp = [data[i][1] for i in range(len(data))]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 4
#       2 import torch
#       3 PTH = r'.\picklefiles'
# ----> 4 with open(f"{PTH}\\eal_test.pkl", 'rb') as eal:
#       5     data = pickle.load(eal)
#       7 ent = [data[i][0] for i in range(len(data))]
#
# FileNotFoundError: [Errno 2] No such file or directory: '.\\picklefiles\\eal_test.pkl'

# %%
import re
def preprocess(text):
    text = text.lower()
    text = re.sub(r"[^\w\s]","",text)
    text = re.sub(r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))","",text)
    text = re.sub("<(\"[^\"]*\"|'[^']*'|[^'\">])*>","",text)    
    return text

# %%
txtemb = embedding.TextEmbedding(device = device)

# %%
sentemb = torch.zeros(len(ent),384).to(device)
for i in tqdm(range(len(ent))):
    token = ent[i]["sentence"]
    sent = preprocess(token)
    output = txtemb(sent)
    sentemb[i] = output
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 4967/4967 [00:42<00:00, 117.31it/s]

# %%
with open(f'{PTH}\\contextemb_test.pkl', 'wb') as f:
    pickle.dump(sentemb, f)
print("Dumped")
f.close()
# Out:
# Dumped
